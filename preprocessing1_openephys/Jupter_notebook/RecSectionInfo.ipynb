# %% [markdown]
# ## Input recording log notes into a new cell!

# %%
import numpy as np
import os
import scipy.io as sio

# %% [markdown]
# ### 2026040417_MST, VPS, and LIP

# %%
# zarya, 20260417

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20260417'
info['pen'] = 30
info['gridtype'] = 'hybrid_centered/angular'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1523, 1540, 1600, 1622, 1703, 1735, 1744]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['SaccadeTraining',  'dots3DMP',  'dots3DMP', 'dots3DMP_fixedRT', 'dots3DMPtuning', 'dots3DMP', 'dots3DMP_fixedRT']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['LIP + MST/VPS']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG', 
                      'Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm', 
                    '22327206141_384ch_20um_45mm']
info['stream_ID'] = ['ProbeA', 
                     'ProbeB']
info['gridxy'] = [[0, -3], 
                  [4, 5]]
info['chanlist'] = [np.arange(1, 385), 
                    np.arange(1, 385)]
info['bank'] = np.array([['Bank A', 'Bank A', 'Bank A', 'Bank A', 'Bank A', 'Bank A', 'Bank A'], 
                         ['single column', 'single column', 'single column', 'single column', 'single column', 'single column', 'single column']], dtype=object)
info['depths'] = np.array([np.ones(info['totalPDS']) * 10000, 
                           np.ones(info['totalPDS']) * 10193]) # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\Neural-Pipeline\data\20260417\zarya20260417dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20260318_LIP

# %%
# zarya, 20260318

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20260318'
info['pen'] = 29
info['gridtype'] = 'hybrid_centered/angular'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1507, 1523, 1540, 1603, 1623, 1643]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['SaccadeTraining', 'SaccadeTraining',  'dots3DMP',  'dots3DMP', 'dots3DMP', 'dots3DMPtuning' ]
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['LIP mapping, fail to get angular grid penetration']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[0, -1]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['Bank C', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 11768]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\Neural-Pipeline\data\20260318\zarya20260318dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20251219

# %%
# zarya, 20251219

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20251219'
info['pen'] = 28
info['gridtype'] = 'original'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1409, 1433, 1501, 1536, 1612, 1630, 1704, 1732]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['SaccadeTraining',  'dots3DMP', 'dots3DMP_fixedRT', 'dots3DMPtuning','SaccadeTraining',  'dots3DMP', 'dots3DMP_fixedRT', 'dots3DMPtuning' ]
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['LIP mapping + fixed RT']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[0, -1]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['Bank C', 'Bank C', 'Bank C', 'Bank C', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 11180]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\Neural-Pipeline\data\20251219\zarya20251219dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20251211

# %%
# zarya, 20251211

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20251211'
info['pen'] = 27
info['gridtype'] = 'original'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1554, 1619, 1636, 1701]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['SaccadeTraining', 'SaccadeTraining', 'dots3DMP_fixedRT',  'dots3DMP']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['LIP mapping, the behavior is not good, focus on saccade training']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[-1, -2]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['Bank B', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 13032]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\Neural-Pipeline\data\20251211\zarya20251211dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250801

# %%
# zarya, 20250801

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250801'
info['pen'] = 26
info['gridtype'] = 'original'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1350, 1407, 1424, 1445, 1506, 1522, 1536]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['SaccadeTraining', 'dots3DMP',  'dots3DMP', 'dots3DMP','dots3DMP', 'dots3DMP', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['LIP mapping']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[0, -3]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 12496]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250801\zarya20250801dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250724

# %%
# zarya, 20250724

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250724'
info['pen'] = 25
info['gridtype'] = 'original'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1435, 1444, 1509, 1527, 1550, 1604, 1626, 1702]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['SaccadeTraining', 'dots3DMP',  'dots3DMP', 'dots3DMP','dots3DMP', 'dots3DMP', 'dots3DMPtuning', 'SaccadeTraining']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['LIP mapping']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[-1, -4]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['bank A', 'bank A','bank A','bank A','bank A','bank A','bank A','single column'] # Bank Config
info['depths'] = [6836, 6836, 6836, 6836, 6836, 6836, 6836, 10722]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250724\zarya20250724dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250718

# %%
# zarya, 20250718

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250718'
info['pen'] = 24
info['gridtype'] = 'original'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1410, 1419, 1427, 1446, 1505, 1526, 1539, 1554]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['SaccadeTraining', 'SaccadeTraining', 'dots3DMP',  'dots3DMP', 'dots3DMP','dots3DMP', 'dots3DMP', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['LIP mapping']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[-2, -2]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 8000]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250718\zarya20250718dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250710

# %%
# zarya, 20250710

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250710'
info['pen'] = 23
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1341, 1358, 1415, 1433, 1448, 1503]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP',  'dots3DMP', 'dots3DMP','dots3DMP', 'dots3DMP', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[5, 4]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 13000]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250710\zarya20250710dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250702

# %%
# zarya, 20250702

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250702'
info['pen'] = 22
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1330, 1349, 1413, 1434, 1505, 1520, 1535]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP',  'dots3DMP', 'dots3DMP','dots3DMP', 'dots3DMP', 'dots3DMPtuning', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[4, 3]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 13800]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250702\zarya20250702dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250602

# %%
# zarya, 20250602

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250602'
info['pen'] = 22
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1250, 1310, 1328, 1350, 1409, 1422]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP',  'dots3DMP', 'dots3DMP','dots3DMP', 'dots3DMP', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[4, 5]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 11975]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250602\zarya20250602dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250523

# %%
# zarya, 20250523

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250523'
info['pen'] = 21
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1326, 1348, 1408, 1429, 1520, 1545]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP',  'dots3DMP', 'dots3DMP','dots3DMP', 'dots3DMPtuning', 'dots3DMP']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[4,4]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 13710]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250523\zarya20250523dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250501

# %%
# zarya, 20250501

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250501'
info['pen'] = 20
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [2502, 5702, 1525, 1555] #1325, 1357
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP',  'dots3DMP', 'dots3DMP', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[5,4]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 11500]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250501\zarya20250501dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250417

# %%
# zarya, 20250417

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250417'
info['pen'] = 19
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1433, 1505, 1529, 1632, 1714, 1742, 1749]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP', 'dots3DMPtuning', 'dots3DMP', 'dots3DMP', 'dots3DMP','dots3DMPtuning', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[4, 3]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 11974]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250417\zarya20250417dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250411

# %%
# zarya, 20250411

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250411'
info['pen'] = 18
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1453, 1554, 1623, 1640, 1654, 1722, 1732]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP',  'dots3DMPtuning', 'dots3DMP', 'dots3DMPtuning', 'dots3DMP','dots3DMP', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327211092_384ch_20um_45mm']
info['gridxy'] = [[4, 5]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'single column', 'single column', 'single column', 'single column', 'single column', 'single column'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 15000]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250411\zarya20250411dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250313

# %%
# zarya, 20250313

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250313'
info['pen'] = 16
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1509, 1546]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMPtuning', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording, but maybe only MSTd']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327206081_384ch_20um_45mm']
info['gridxy'] = [[4, 3]]
info['chanlist'] = np.arange(1, 385)  
info['bank'] = ['single column', 'Bank C'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 15228]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250313\zarya20250313dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20250306

# %%
# zarya, 20250306

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20250306'
info['pen'] = 15
info['gridtype'] = 'angled_15'

# File paths
info['filepath'] = f"D:\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1447, 1509, 1529, 1559]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP', 'dots3DMP', 'dots3DMPtuning', 'dots3DMP']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['dual recording, but maybe only MSTd']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327206081_384ch_20um_45mm']
info['gridxy'] = [[4, 4]]
info['chanlist'] = np.arange(1, 385)  # Channels 1-384
info['bank'] = ['customized', 'customized', 'customized', 'customized'] # Bank Config
info['depths'] = [np.ones(info['totalPDS']) * 16745]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
# Out:
# Saving file to: D:\20250306\zarya20250306dots3DMP_info.mat
# File saved successfully!

# %% [markdown]
# ### 20241220

# %%
# zarya, 20241220

info = {}

# Fixed information
info['subject'] = 'zarya'
info['date'] = '20241220'
info['pen'] = 14
info['gridtype'] = 'original'

# File paths
info['filepath'] = f"D:\\Neural-Pipeline\\data\\{info['date']}\\" 
info_filepath = os.path.join(info['filepath'], f"{info['subject']}{info['date']}dots3DMP_info.mat")

# Task-specific information
info['pldaps_filetimes'] = [1440, 1507, 1524, 1622, 1538, 1704]
info['totalPDS'] = len(info['pldaps_filetimes'])
info['trellis_filenums'] = np.ones(info['totalPDS'], dtype=int)
info['par'] = ['dots3DMP', 'dots3DMP', 'dots3DMP', 'dots3DMP', 'dots3DMPtuning', 'dots3DMPtuning']
info['rec_group'] = np.ones(info['totalPDS'], dtype=int)
info['comments'] = ['']

# Probe information
info['probe_type'] = ['Neuropixels 1.0 NHP LONG']
info['probe_ID'] = ['22327206081_384ch_20um_45mm']
info['gridxy'] = [[3, -3]]
info['chanlist'] = np.arange(1, 385)  # Channels 1-384
info['depths'] = [np.ones(info['totalPDS']) * 11000]  # MDI depth

# Save the experiment Info
print(f"Saving file to: {info_filepath}")
os.makedirs(os.path.dirname(info_filepath), exist_ok=True)
sio.savemat(info_filepath, {'info': info})
print("File saved successfully!")
